# %% [markdown]
# # 머신러닝이란?

# %% [raw]
# - 명시적인 프로그래밍 없이 컴퓨터가 학습하는 능력을 갖게 하는 것
# - 어떤 작업 T에 대한 컴퓨터 프로그램의 성능을 P로 측정했을 때 경험 E로 인해 성능이 향상됐다면
#     이 컴퓨터 프로그램은 작업 T와 성능 측정 P에 대해 경험 E로 학습한 것
#     >>> ?
#     >>>
#         예를 들면
#             T: 스팸 메일 구분
#             E: 훈련 데이터
#             P: 성능 (ex. 정확도)

# %% [markdown]
# # 왜 머신러닝?

# %% [markdown]
# ### 1. 전통적인 프로그래밍 VS 머신러닝

# %% [raw]
# 전통적인 프로그래밍
#     과정: 문제 연구 --> 규칙 작성 --> 테스트 --> 배포
#     단점: 유지보수가 힘듦: 새로운 규칙 추가가 힘듦, 처음에 규칙을 만드는 것이 복잡함
#
# 머신러닝
#     과정: 문제 연구 --> 데이터를 이용해 머신러닝 알고리즘 훈련 --> 테스트 --> 배포
#     머신러닝은 배포 후에도 새로운 데이터를 받아들이면서 훈련 --> 알아서 개선

# %% [markdown]
# ### 2. 전통적인 방식으론 너무 복잡하거나, 알려진 알고리즘이 없는 경우

# %% [raw]
# 대표 사례: 음성 인식 (말고는 없을까)
#     >>> 각 단어를 녹음한 샘플을 사용해 스스로 학습하는 알고리즘을 작성하도록 함

# %% [markdown]
# ### 3. 머신러닝을 통해 배울 수 있음

# %% [raw]
# 학습 내용을 조사해 새로운 통찰 얻기

# %% [markdown]
# # 머신러닝 시스템의 종류

# %% [raw]
# 분류
#     1. 사람의 감독 하에 훈련하는 것인지 여부: 지도, 비지도, 준지도, 강화 학습
#     2. 실시간 점진적 학습 여부: 온라인, 배치 학습
#     3. 단순하게 알고 있는 데이터 포인트와 새 데이터 포인트를 비교하는 것인지, 아니면 훈련 데이터셋에서 패턴을 발견하여 예측 모델을 만드는 것인지: 사례 기반, 모델 기반 학습

# %% [markdown]
# ### 1. 사람의 감독 하에 훈련하는 것인지 여부

# %% [raw]
#     1. 지도 학습
#         알고리즘에 주입하는 훈련 데이터에 레이블이라는 원하는 답이 포함된 학습유형
#         대표 사례:
#             분류(스팸 분류)
#             회귀(타깃 수치 예측(ex. 중고차 가격)) >>> 예측 변수와 레이블(여기선 중고차 가격)이 포함된 데이터가 많이 필요
#         대표 알고리즘
#             KNN
#             선형 회귀
#             로지스틱 회귀
#             SVM
#             결정 트리, 랜덤 포레스트
#             NNW
#
#     2. 비지도 학습
#         훈련 데이터에 레이블이 없는 경우
#         대표 사례
#             블로그 방문자 분석
#             이상치 탐지
#             연관 규칙 학습
#         대표 알고리즘
#             군집 (clustering)
#                 Kmeans
#                 계층 군집 분석
#                 기댓갑 최대화
#             시각화, 차원 축소
#                 주성분 분석 (PCA: Principal Component Analysis)
#                 커널 PCA
#                 지역적 선형 임베딩
#                 t-SNE (t-distributed Stochastic Neighbor Embedding)
#             연관 규칙 학습
#                 어프라이어리
#                 이클렛
#
#         3. 준지도 학습
#             레이블이 일부만 있는 경우
#
#         4. 강화 학습
#             학습하는 시스템(에이전트)의 행동에 따른 결과로 보상 / 벌점을 줌으로써, 시간이 지나면서 가장 큰 보상을 얻기 위한 최상의 전략을 스스로 학습하도록 하는 경우
#             대표 사례
#                 알파고

# %% [markdown]
# ### 2. 실시간 점진적 학습 여부: 온라인, 배치 학습

# %% [raw]
#     1. 배치 학습
#         aka 오프라인 학습
#         한꺼번에 학습 --> 적용 >>> 추가 학습 X, 배운 것 적용만
#         추가학습 하려면 처음부터 새로 학습 + 새 시스템으로 교체
#         빠른 변화에 적응 필요 + 자원 제한 시 부적격
#     2. 온라인 학습
#         aka 점진적 학습
#         데이터를 하나씩 / 미니배치 단위로 학습 >>> 빠름 + 저비용 + 실시간
#         학습률이 중요한 파라미터
#             >>> 데이터 변화에 얼마나 민감하게 반응할 것인지에 대한 정도
#         나쁜 데이터 주입 시 성능 저하 발생 >>> 이상 탐지 시 학습 중지 OR 롤백

# %% [markdown]
# ### 3. 사례 기반, 모델 기반: 시스템을 어떻게 일반화하는가

# %% [raw]
#     1. 사례 기반
#         사례를 기억해 학습 --> 유사도 측정 --> 새로운 데이터에 일반화
#
#     2. 모델 기반
#         모델을 만들어 예측

# %% [raw]
# 모델 기반은 일반화라고 볼 수 있는가?
# 주가 예측에 적합한 시스템은?
# 주가가 상승할 확률을 알려면 어떤 시스템이 적합한가?
# 좋은 매도 타이밍을 잡기 위해선 어떤 시스템이 적합한가?
# 부동산 정보 예측엔 어떤 시스템이 적합한가?

# %% [markdown]
# # 머신러닝의 주요 도전 과제: 주의사항

# %% [raw]
# 1. 낮은 품질의 자료
#     - 양이 너무 적음
#     - 대표성이 떨어짐
#         샘플링 잡음: 너무 적어서 생기는, 우연에 의한, 대표성 없는 데이터
#         샘플링 편향: 많아도 표본 선정이 잘못되어 특정 성향의 데이터만 선정
#     - 에러, 이상치, 잡음 >>> NA, 너무 크거나 작은 값 등
#     - 관련 없는 특성
#
# 2. 과대 / 과소 적합
#     과대 적합: 모델이 훈련 데이터에 너무 잘 맞지만 일반성이 떨어지는 것, 잡음의 양에 비해 모델이 너무 복잡할 때
#         해결
#             파라미터 / 특성 수 감소
#             모델에 제약 추가: 하이퍼파라미터 튜닝 (규제 추가, 감소)
#             훈련 데이터 추가 확보
#             훈련 데이터의 잡음 감소 (fillna, drop, replace, normalization, ...)
#             *** 자유도 감소: 조절할 수 있는 변수를 줄이는 것
#
#     과소 적합: 과대 적합의 반대

# %% [raw]
# 하이퍼파라미터?
#     사용자가 모델에 직접 설정하는 요소
#         ex. KNN의 k값, 학습률, 신경망의 은닉층 개수, ...
#     휴리스틱한 방법, 경험적 방법 등으로 최적 하이퍼파라미터 결정
#         >>> 여러 값을 넣어 바꿔보거나, 써봤을 때 가장 좋았던 것이라던가, ...

# %% [markdown]
# # 테스트 및 검증

# %% [raw]
# 과정
#     1. 훈련 데이터를 훈련 세트와 테스트 세트로 분할
#     2. 훈련 세트로 모델 훈련
#     3. 테스트 세트로 모델 평가: 일반화 오차 측정 (새로운 샘플에 모델이 얼마나 잘 작동하는지 여부)
#     4. 훈련 오차가 낮지만 일반화 오차가 높다면 과대 적합 >>> 모델 수정
#
# 검증 세트
#     테스트 세트엔 잘 맞지만, 실제 서비스에선 잘 맞지 않는 경우를 예방하기 위한 방법
#     훈련 세트, 테스트 세트에서 추가로 나눠서 만듦 >>> 원본을 총 3개로 나누는 것
#
# 교차 검증
#     검증 세트로 너무 많이 차지하는 것을 막기 위한 방법
#     교차 검증을 이용한 모델 구축 과정
#         훈련 세트를 여러 서브셋으로 나눔
#         각 모델을 서브셋의 조합으로 훈련
#         나머지를 검증 세트로 사용
#         모델, 하이퍼파라미터가 정해지면 전체 훈련 데이터를 사용하여 선택한 파라미터로 최종 모델 훈련
#         테스트 세트에서 일반화 오차 측정
#
# *** >>>  어떤 모델이 잘 맞는지는 평가해보기 전까지 알 수 없음  <<<

# %% [raw]
# 정리
#
# 머신러닝을 어떻게 정의하는가?
#     >>> 어떤 경험을 통해 작업 성능이 향상되도록 하는 것
#     >>> 데이터로부터 학습하도록 프로그래밍 하는 것
#
# 머신러닝이 도움을 줄 수 있는 문제 유형
#     >>>
#         1. 기존 방식으론 많은 수동 조정과 규칙이 필요한 경우
#         2. 전통적인 방식으로는 전혀 해결 방법이 없는, 복잡한 문제
#         3. 유동적인 환경
#         4. 복잡한 문제와 대량의 데이터로부터 통찰을 얻고자 할 때
#
# 레이블된 훈련 세트란?
#     >>> 원하는 답이 자료 내에 있는 자료 (ex. 중고차 가격, 붓꽃 품종, 주식 가격)
#
# 가장 널리 사용되는 지도 학습 작업
#     >>> 분류, 회귀
#
# 보편적인 비지도 학습 작업
#     >>> 군집화, 시각화, 차원 축소, 연관 규칙 학습
#
# 사전 정보가 없는 여러 지형에서 로봇을 걸어가게 하도록 하기 위해 사용할 수 있는 알고리즘
#     >>> 강화 학습
#
# 고객을 여러 그룹으로 분할하기 위해 사용할 수 있는 알고리즘
#     >>> 비지도 학습: Kmeans
#     >>> 지도학습: SVM
#
# 스팸 감지는 어떤 학습 종류라고 할 수 있는가
#     >>> 준지도 학습: 사용자 별로 어떤 것을 스팸으로 분류하라고 하는지 설정해놓은 경우가 있음
#         (ex. 해당 이메일 주소로 오는 메일은 스팸으로 설정)
#     >>> 비지도 학습: 특정 문자열 조합을 스스로 탐색
#
# 온라인 학습 시스템이란?
#     >>> 데이터를 한꺼번에 학습하는 것이 아닌, 하나씩/미니 배치 단위로 학습하는 시스템
#     >>> 실시간 환경, 처리 비용이 적어야 하는 환경에 적합
#     >>> 나쁜 데이터 주입 시 성능 저하 발생 가능성 존재
#
# 예측을 하기 위해 유사도 측정에 의존하는 학습 알고리즘은?
#     >>> 사례 기반 학습 알고리즘
#
# 모델 파라미터와 하이퍼파라미터의 차이는?
#     >>> 모델 파라미터: 모델이 알아서 결정
#     >>> 하이퍼파라미터: 개발자가 직접 결정
#
# 머신러닝의 주요 도전 과제는?
#     >>>
#         1.낮은 품질의 데이터
#             - 양이 너무 적은 경우
#             - 특이값, 결측치가 너무 많은 경우
#             - 샘플링 편향, 샘플링 잡음이 있는 경우
#             - 관련 없는 특성이 있는 경우
#         2. 과대 / 과소 적합
#
# 훈련 데이터에서의 성능은 좋지만 새로운 샘플에서의 일반화 성능이 나쁘다면 그 해결책은?
#     >>>
#         다른 모델 사용
#         하이퍼파라미터 조정
#         데이터에서 사용할 특성 감소
#
# 테스트 세트란 무엇이고 사용 목적은?
#     >>>
#         구축한 모델이 얼마나 잘 작동하는지 확인하기 위해 나눈 데이터셋
#
# 검증 세트의 목적은?
#     >>> 교차 검증을 통해 테스트 세트에 너무 잘 맞추게 되어 실제 서비스에선 잘 맞지 않게 되는 경우를 방지하는 것
#
# 테스트 세트를 사용해 하이퍼파라미터를 튜닝할 경우 생길 수 있는 문제는?
#     >>> 테스트 세트에만 잘 맞추게 되어 실제 서비스에선 잘 맞지 않게 될 수도 있음
#
# 교차 검증이 무엇이고, 왜 하나의 검증세트보다 선호하는가?
#     >>> 훈련 세트를 여러 개로 나눠, 이들 일부의 조합으로 훈련시키고, 나머지를 검증 세트로 사용해 테스트하는 것
#     >>> 답: 검증 세트를 별도로 분리하지 않고 모델 선택과 하이퍼파라미터 튜닝을 위해 모델을 비교할 수 있는 기술. 훈련 데이터를 최대한 활용할 수 있도록 도와줌.
